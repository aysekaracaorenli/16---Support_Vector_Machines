# %% [markdown]
# # Support Vector Machines with Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# ## Get the Data

# %%
df = pd.read_table('diabetesdata.txt')
y = df['Diabetes']
X = df[['BMI','Glucose']]
X
# Out:
#       BMI  Glucose
# 0    33.6      148
# 1    26.6       85
# 2    23.3      183
# 3    28.1       89
# 4    43.1      137
# ..    ...      ...
# 763  32.9      101
# 764  36.8      122
# 765  26.2      121
# 766  30.1      126
# 767  30.4       93
#
# [768 rows x 2 columns]

# %% [markdown]
# ## Train Test Split and Standardize

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=5,stratify=y)
scaler = preprocessing.StandardScaler()
scaler.fit(X_train)
X_trainStandard = scaler.transform(X_train)
X_testStandard = scaler.transform(X_test)

# %% [markdown]
# # Train the Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
SVC()

# %%
model = SVC(C=1,kernel='linear')
model.fit(X_trainStandard,y_train)
# Out:
# SVC(C=1, kernel='linear')

# %% [markdown]
# ## Predictions and Evaluations
#
# Now let's predict using the trained model.

# %%
predictions = model.predict(X_testStandard)
model.score(X_testStandard,y_test)
# Out:
# 0.7337662337662337

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,predictions))
# Out:
# [[89 11]
#  [30 24]]

# %%
#Functions to plot decision boundaries
def make_meshgrid(x, y, h=.02):
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    return xx, yy

def plot_contours(ax, clf, xx, yy, **params):
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    return out

# %%
fig, ax = plt.subplots()
# title for the plots
title = ('Decision surface of SVC ')
# Set-up grid for plotting.
X0, X1 = X_trainStandard[:, 0], X_trainStandard[:, 1]
xx, yy = make_meshgrid(X0, X1)

plot_contours(ax, model, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
ax.scatter(X0, X1, c=y_train, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
ax.set_ylabel('Glucose')
ax.set_xlabel('BMI')
ax.set_xticks(())
ax.set_yticks(())
ax.set_title(title)
plt.show()

# %%
model = SVC(C=1,kernel='poly')
model.fit(X_trainStandard,y_train)
fig, ax = plt.subplots()
# title for the plots
title = ('Decision surface of SVC ')
# Set-up grid for plotting.
X0, X1 = X_trainStandard[:, 0], X_trainStandard[:, 1]
xx, yy = make_meshgrid(X0, X1)

plot_contours(ax, model, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
ax.scatter(X0, X1, c=y_train, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
ax.set_ylabel('Glucose')
ax.set_xlabel('BMI')
ax.set_xticks(())
ax.set_yticks(())
ax.set_title(title)
plt.show()

# %%
predictions = model.predict(X_testStandard)
model.score(X_testStandard,y_test)
# Out:
# 0.7207792207792207

# %%
model = SVC(C=0.1,kernel='rbf')
model.fit(X_trainStandard,y_train)
fig, ax = plt.subplots()
# title for the plots
title = ('Decision surface of SVC ')
# Set-up grid for plotting.
X0, X1 = X_trainStandard[:, 0], X_trainStandard[:, 1]
xx, yy = make_meshgrid(X0, X1)

plot_contours(ax, model, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
ax.scatter(X0, X1, c=y_train, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
ax.set_ylabel('Glucose')
ax.set_xlabel('BMI')
ax.set_xticks(())
ax.set_yticks(())
ax.set_title(title)
plt.show()

# %%
predictions = model.predict(X_testStandard)
model.score(X_testStandard,y_test)
# Out:
# 0.7207792207792207

# %%
model = SVC(C=1,kernel='rbf')
model.fit(X_trainStandard,y_train)
fig, ax = plt.subplots()
# title for the plots
title = ('Decision surface of SVC ')
# Set-up grid for plotting.
X0, X1 = X_trainStandard[:, 0], X_trainStandard[:, 1]
xx, yy = make_meshgrid(X0, X1)

plot_contours(ax, model, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
ax.scatter(X0, X1, c=y_train, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
ax.set_ylabel('Glucose')
ax.set_xlabel('BMI')
ax.set_xticks(())
ax.set_yticks(())
ax.set_title(title)
plt.show()

# %%
predictions = model.predict(X_testStandard)
model.score(X_testStandard,y_test)
# Out:
# 0.7337662337662337

# %%
model = SVC(C=10,kernel='rbf')
model.fit(X_trainStandard,y_train)
fig, ax = plt.subplots()
# title for the plots
title = ('Decision surface of SVC ')
# Set-up grid for plotting.
X0, X1 = X_trainStandard[:, 0], X_trainStandard[:, 1]
xx, yy = make_meshgrid(X0, X1)

plot_contours(ax, model, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
ax.scatter(X0, X1, c=y_train, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
ax.set_ylabel('Glucose')
ax.set_xlabel('BMI')
ax.set_xticks(())
ax.set_yticks(())
ax.set_title(title)
plt.show()

# %%
predictions = model.predict(X_testStandard)
model.score(X_testStandard,y_test)
# Out:
# 0.7532467532467533

# %%
model = SVC(C=1000,kernel='rbf')
model.fit(X_trainStandard,y_train)
fig, ax = plt.subplots()
# title for the plots
title = ('Decision surface of SVC ')
# Set-up grid for plotting.
X0, X1 = X_trainStandard[:, 0], X_trainStandard[:, 1]
xx, yy = make_meshgrid(X0, X1)

plot_contours(ax, model, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
ax.scatter(X0, X1, c=y_train, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
ax.set_ylabel('Glucose')
ax.set_xlabel('BMI')
ax.set_xticks(())
ax.set_yticks(())
ax.set_title(title)
plt.show()

# %%
predictions = model.predict(X_testStandard)
model.score(X_testStandard,y_test)
# Out:
# 0.7337662337662337

# %% [markdown]
# # With all variables

# %%
df = pd.read_table('diabetesdata.txt')
X = df.drop('Diabetes',axis=1)
y = df['Diabetes']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=35,stratify=y)
scaler = preprocessing.StandardScaler()
scaler.fit(X_train)
X_trainStandard = scaler.transform(X_train)
X_testStandard = scaler.transform(X_test)

# %%
model = SVC(C=1,kernel='linear')
model.fit(X_trainStandard,y_train)

# %%
predictions = model.predict(X_testStandard)
model.score(X_testStandard,y_test)

# %%
print(confusion_matrix(y_test,predictions))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
pipe=Pipeline([('scaler',preprocessing.StandardScaler()),('Classifier',SVC())])
tuned_parameters = [{'Classifier__kernel': ['rbf'], 
                     'Classifier__gamma': [1,0.1,0.01,0.001],
                     'Classifier__C': [1, 10, 100, 1000]},
                    {'Classifier__kernel': ['linear'], 'Classifier__C': [1, 10, 100, 1000]},
                   {'Classifier__kernel':['poly'], 'Classifier__C':[1, 10, 100, 1000]}]
grid = GridSearchCV(pipe,tuned_parameters,refit=True,verbose=2,scoring='accuracy')
# May take awhile!
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.001, Classifier__kernel=rbf; total time=   0.0s
# [CV] END .........Classifier__C=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END .........Classifier__C=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END .........Classifier__C=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END .........Classifier__C=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END .........Classifier__C=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END ........Classifier__C=10, Classifier__kernel=linear; total time=   0.0s
# [CV] END ........Classifier__C=10, Classifier__kernel=linear; total time=   0.0s
# [CV] END ........Classifier__C=10, Classifier__kernel=linear; total time=   0.0s
# [CV] END ........Classifier__C=10, Classifier__kernel=linear; total time=   0.0s
# [CV] END ........Classifier__C=10, Classifier__kernel=linear; total time=   0.0s
# [CV] END .......Classifier__C=100, Classifier__kernel=linear; total time=   0.1s
# [CV] END .......Classifier__C=100, Classifier__kernel=linear; total time=   0.1s
# [CV] END .......Classifier__C=100, Classifier__kernel=linear; total time=   0.1s
# [CV] END .......Classifier__C=100, Classifier__kernel=linear; total time=   0.1s
# [CV] END .......Classifier__C=100, Classifier__kernel=linear; total time=   0.1s
# [CV] END ......Classifier__C=1000, Classifier__kernel=linear; total time=   1.5s
# [CV] END ......Classifier__C=1000, Classifier__kernel=linear; total time=   1.8s
# [CV] END ......Classifier__C=1000, Classifier__kernel=linear; total time=   1.1s
# [CV] END ......Classifier__C=1000, Classifier__kernel=linear; total time=   1.6s
# [CV] END ......Classifier__C=1000, Classifier__kernel=linear; total time=   1.9s
# [CV] END ...........Classifier__C=1, Classifier__kernel=poly; total time=   0.0s
# [CV] END ...........Classifier__C=1, Classifier__kernel=poly; total time=   0.0s
# [CV] END ...........Classifier__C=1, Classifier__kernel=poly; total time=   0.0s
# [CV] END ...........Classifier__C=1, Classifier__kernel=poly; total time=   0.0s
# [CV] END ...........Classifier__C=1, Classifier__kernel=poly; total time=   0.0s
# [CV] END ..........Classifier__C=10, Classifier__kernel=poly; total time=   0.0s
# [CV] END ..........Classifier__C=10, Classifier__kernel=poly; total time=   0.0s
# [CV] END ..........Classifier__C=10, Classifier__kernel=poly; total time=   0.0s
# [CV] END ..........Classifier__C=10, Classifier__kernel=poly; total time=   0.0s
# [CV] END ..........Classifier__C=10, Classifier__kernel=poly; total time=   0.0s
# [CV] END .........Classifier__C=100, Classifier__kernel=poly; total time=   0.0s
# [CV] END .........Classifier__C=100, Classifier__kernel=poly; total time=   0.0s
# [CV] END .........Classifier__C=100, Classifier__kernel=poly; total time=   0.1s
# [CV] END .........Classifier__C=100, Classifier__kernel=poly; total time=   0.0s
# [CV] END .........Classifier__C=100, Classifier__kernel=poly; total time=   0.0s
# [CV] END ........Classifier__C=1000, Classifier__kernel=poly; total time=   0.8s
# [CV] END ........Classifier__C=1000, Classifier__kernel=poly; total time=   0.9s
# [CV] END ........Classifier__C=1000, Classifier__kernel=poly; total time=   1.4s
# [CV] END ........Classifier__C=1000, Classifier__kernel=poly; total time=   1.8s
# [CV] END ........Classifier__C=1000, Classifier__kernel=poly; total time=   0.5s
# GridSearchCV(estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('Classifier', SVC())]),
#              param_grid=[{'Classifier__C': [1, 10, 100, 1000],
#                           'Classifier__gamma': [1, 0.1, 0.01, 0.001],
#                           'Classifier__kernel': ['rbf']},
#                          {'Classifier__C': [1, 10, 100, 1000],
#                           'Classifier__kernel': ['linear']},
#                          {'Classifier__C': [1, 10, 100, 1000],
#                           'Classifier__kernel': ['poly']}],
#              scoring='accuracy', verbose=2)

# %%
print(grid.best_params_)
# Out:
# {'Classifier__C': 10, 'Classifier__gamma': 0.001, 'Classifier__kernel': 'rbf'}

# %%
model = SVC(C=10,gamma=0.001,kernel='rbf')
model.fit(X_trainStandard,y_train)
predictions = model.predict(X_testStandard)

# %%
model.score(X_testStandard,y_test)
# Out:
# 0.7792207792207793

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[89 11]
#  [23 31]]
